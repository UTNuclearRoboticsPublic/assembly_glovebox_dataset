# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("J_NG_G_3284.0.png")
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_image)

# %%
# lower_range = np.array([23, 77, 48])
# upper_range = np.array([80, 161, 118])

lower_range = np.array([22, 76, 47])
upper_range = np.array([57, 187, 127])


mask = cv2.inRange(rgb_image, lower_range, upper_range)
rgb_image[mask != 0] = [0, 0, 0]

plt.imshow(rgb_image)

# %%
img2 = cv2.imread("green_removed.png")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
img3 = np.where((img2 == [0, 0, 0]), [0, 0, 0], [255, 255, 255])

img3 = np.where((img3 == [0, 255, 255]), [255, 255, 255], img3)

img3 = np.where((img3 == [255, 255, 0]), [255, 255, 255], img3)

# %%
binary = (img2 > 0).astype(np.uint8) * 255

# %%
plt.imshow(binary)

# %%
img3.shape
# Out:
# (720, 1280, 3)

# %%
img3[280:300, 190:200]
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(img3, cmap="binary")

# %%
img3[425, 550, :]
# Out:
# array([255, 255, 255])

# %%
img2[560, 900, :]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
plt.imshow(img2)

# %%
binary = img2[img2 == [0, 0, 0]]
